# %% [markdown]
# # 📺 Amazon Prime Video Data Analysis
#
# This notebook provides an exploratory data analysis (EDA) of Amazon Prime Video content using a sample dataset. The goal is to uncover trends, insights, and key patterns in the platform's content library.
#
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Display settings
pd.set_option('display.max_columns', None)
sns.set(style='whitegrid')

# %%
# Load the dataset
df = pd.read_csv("amazon_prime_sample.csv")
df.head()
# Out:
#                        title     type  release_year   duration rating  \
# 0                   The Boys  TV Show          2019  2 Seasons  TV-MA
# 1                  Jack Ryan  TV Show          2018  2 Seasons  TV-MA
# 2                    Fleabag  TV Show          2016  2 Seasons  TV-MA
# 3  The Marvelous Mrs. Maisel  TV Show          2017  4 Seasons  TV-14
# 4                 Invincible  TV Show          2021   1 Season  TV-MA
#
#        genre country          date_added
# 0     Action     USA       July 26, 2019
# 1     Action     USA     August 31, 2018
# 2     Comedy      UK  September 16, 2016
# 3      Drama     USA      March 17, 2017
# 4  Animation     USA      March 26, 2021

# %%
# Dataset info
df.info()

# Check for nulls
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         5 non-null      object
#  1   type          5 non-null      object
#  2   release_year  5 non-null      int64
#  3   duration      5 non-null      object
#  4   rating        5 non-null      object
#  5   genre         5 non-null      object
#  6   country       5 non-null      object
#  7   date_added    5 non-null      object
# dtypes: int64(1), object(7)
# memory usage: 452.0+ bytes
# title           0
# type            0
# release_year    0
# duration        0
# rating          0
# genre           0
# country         0
# date_added      0
# dtype: int64

# %%
# Unique values in 'type', 'rating', and 'genre'
print("Unique types:", df['type'].unique())
print("Unique ratings:", df['rating'].unique())
print("Unique genres:", df['genre'].unique())
# Out:
# Unique types: ['TV Show']
# Unique ratings: ['TV-MA' 'TV-14']
# Unique genres: ['Action' 'Comedy' 'Drama' 'Animation']

# %%
# Count of content by type (Movie or TV Show)
sns.countplot(data=df, x='type', palette='viridis')
plt.title("Count of TV Shows and Movies on Amazon Prime")
plt.show()
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_16464\1968183503.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='type', palette='viridis')

# %%
# Number of content released per year
plt.figure(figsize=(10,6))
df['release_year'].value_counts().sort_index().plot(kind='bar', color='skyblue')
plt.title("Content Release Trend by Year")
plt.xlabel("Year")
plt.ylabel("Number of Releases")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# Distribution of content by rating
plt.figure(figsize=(8,5))
sns.countplot(data=df, y='rating', order=df['rating'].value_counts().index, palette='magma')
plt.title("Content Ratings Distribution")
plt.xlabel("Count")
plt.ylabel("Rating")
plt.show()
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_16464\4202397792.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, y='rating', order=df['rating'].value_counts().index, palette='magma')

# %%
# Genre distribution
plt.figure(figsize=(8,5))
sns.countplot(data=df, y='genre', order=df['genre'].value_counts().index, palette='coolwarm')
plt.title("Content Genres on Amazon Prime")
plt.xlabel("Count")
plt.ylabel("Genre")
plt.show()
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_16464\1808853826.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, y='genre', order=df['genre'].value_counts().index, palette='coolwarm')
